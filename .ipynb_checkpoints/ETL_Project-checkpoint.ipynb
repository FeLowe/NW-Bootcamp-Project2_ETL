# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
wine_file = "Resources/wine_data.csv"
wine_df = pd.read_csv(wine_file, encoding='latin-1')
wine_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                       VulkÃ  Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN     Kerin OâKeefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                 Nicosia 2013 VulkÃ  Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2          @paulgwineÂ       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4          @paulgwineÂ   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
new_wine_df = wine_df[["Unnamed: 0","country","designation","points", "price", "variety"]].copy()
new_wine_df.head()
# Out:
#    Unnamed: 0   country                         designation  points  price  \
# 0           0     Italy                       VulkÃ  Bianco      87    NaN
# 1           1  Portugal                            Avidagos      87   15.0
# 2           2        US                                 NaN      87   14.0
# 3           3        US                Reserve Late Harvest      87   13.0
# 4           4        US  Vintner's Reserve Wild Child Block      87   65.0
#
#           variety
# 0     White Blend
# 1  Portuguese Red
# 2      Pinot Gris
# 3        Riesling
# 4      Pinot Noir

# %%
country_file = "Resources/country_data.csv"
country_df = pd.read_csv(country_file)
country_df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
# 2         -0,39                                 31              6000.0
# 3        -20,71                               9,27              8000.0
# 4           6,6                               4,05             19000.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36,0               3,2      12,13      0,22     87,65       1
# 1         86,5              71,2      21,09      4,42     74,49       3
# 2         70,0              78,1       3,22      0,25     96,53       1
# 3         97,0             259,5         10        15        75       2
# 4        100,0             497,2       2,22         0     97,78       3
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46,6     20,34        0,38     0,24    0,38
# 1     15,11      5,22       0,232    0,188   0,579
# 2     17,14      4,61       0,101      0,6   0,298
# 3     22,46      3,27         NaN      NaN     NaN
# 4      8,71      6,25         NaN      NaN     NaN

# %%
new_country_df = country_df[["Country", "Climate"]].copy()
new_country_df.head()
# Out:
#            Country Climate
# 0     Afghanistan        1
# 1         Albania        3
# 2         Algeria        1
# 3  American Samoa        2
# 4         Andorra        3

# %% [markdown]
# ### Transform wine DataFrame

# %%
#confirming columns match order of wine table in database
wine_cols = list(new_wine_df)
wine_cols
# Out:
# ['Unnamed: 0', 'country', 'designation', 'points', 'price', 'variety']

# %%
#rename the column headers
wine_transformed = new_wine_df.rename(columns={'Unnamed: 0': 'id','points': 'score'})

#set index
wine_transformed.set_index("id", inplace=True)

wine_transformed.head()
# Out:
#      country                         designation  score  price         variety
# id
# 0      Italy                       VulkÃ  Bianco     87    NaN     White Blend
# 1   Portugal                            Avidagos     87   15.0  Portuguese Red
# 2         US                                 NaN     87   14.0      Pinot Gris
# 3         US                Reserve Late Harvest     87   13.0        Riesling
# 4         US  Vintner's Reserve Wild Child Block     87   65.0      Pinot Noir

# %%
#rename the column headers
wine_transformed = new_wine_df.rename(columns={'Unnamed: 0': 'id','points': 'score'})

#set index
wine_transformed.set_index("id", inplace=True)

#drop NaN values
wine_transformed = wine_transformed.dropna()

wine_transformed.head()
# Out:
#      country                         designation  score  price  \
# id
# 1   Portugal                            Avidagos     87   15.0
# 3         US                Reserve Late Harvest     87   13.0
# 4         US  Vintner's Reserve Wild Child Block     87   65.0
# 5      Spain                        Ars In Vitro     87   15.0
# 6      Italy                             Belsito     87   16.0
#
#                variety
# id
# 1       Portuguese Red
# 3             Riesling
# 4           Pinot Noir
# 5   Tempranillo-Merlot
# 6             Frappato

# %% [markdown]
# ### Transform country DatFrame

# %%
#confirming columns match order of country table in database
country_cols = list(new_country_df)
country_cols
# Out:
# ['Country', 'Climate']

# %%
#rename the column headers
country_transformed = new_country_df.rename(columns={'Country': 'country','Climate': 'climate'})

#create new index field
country_transformed['id'] = country_transformed.index

#set index
country_transformed.set_index("id", inplace=True)

#drop NaN values
country_transformed = country_transformed.dropna()

country_transformed.head()
# Out:
#             country climate
# id
# 0      Afghanistan        1
# 1          Albania        3
# 2          Algeria        1
# 3   American Samoa        2
# 4          Andorra        3

# %% [markdown]
# ### Create database connection

# %%
rds_connection_string = "root:{Your-Password-Here}@127.0.0.1/wine_climate_db"
engine = create_engine(f'mysql://{rds_connection_string}', encoding='latin-1', echo=True)

# %%
engine.table_names()
# Out:
# 2019-05-11 15:30:56,581 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2019-05-11 15:30:56,596 INFO sqlalchemy.engine.base.Engine ()
# 2019-05-11 15:30:56,601 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2019-05-11 15:30:56,603 INFO sqlalchemy.engine.base.Engine ()
# 2019-05-11 15:30:56,607 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2019-05-11 15:30:56,609 INFO sqlalchemy.engine.base.Engine ()
# 2019-05-11 15:30:56,610 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2019-05-11 15:30:56,611 INFO sqlalchemy.engine.base.Engine ()
# 2019-05-11 15:30:56,614 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2019-05-11 15:30:56,615 INFO sqlalchemy.engine.base.Engine ()
# 2019-05-11 15:30:56,617 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2019-05-11 15:30:56,618 INFO sqlalchemy.engine.base.Engine ()
# 2019-05-11 15:30:56,620 INFO sqlalchemy.engine.base.Engine SELECT CAST('test collated returns' AS CHAR CHARACTER SET utf8mb4) COLLATE utf8mb4_bin AS anon_1
# 2019-05-11 15:30:56,621 INFO sqlalchemy.engine.base.Engine ()
# 2019-05-11 15:30:56,624 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `wine_climate_db`
# 2019-05-11 15:30:56,625 INFO sqlalchemy.engine.base.Engine ()
# ['country_climates', 'wines']

# %% [markdown]
# ### Load DataFrames into database

# %%
wine_transformed.to_sql(name='wines', con=engine, if_exists='append', index=True)
# Out:
# 2019-05-11 15:30:56,690 INFO sqlalchemy.engine.base.Engine DESCRIBE `wines`
# 2019-05-11 15:30:56,692 INFO sqlalchemy.engine.base.Engine ()
# 2019-05-11 15:30:56,750 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-05-11 15:30:57,901 INFO sqlalchemy.engine.base.Engine INSERT INTO wines (id, country, designation, score, price, variety) VALUES (%s, %s, %s, %s, %s, %s)
# 2019-05-11 15:30:57,903 INFO sqlalchemy.engine.base.Engine ((1, 'Portugal', 'Avidagos', 87, 15.0, 'Portuguese Red'), (3, 'US', 'Reserve Late Harvest', 87, 13.0, 'Riesling'), (4, 'US', "Vintner's Reserve Wild Child Block", 87, 65.0, 'Pinot Noir'), (5, 'Spain', 'Ars In Vitro', 87, 15.0, 'Tempranillo-Merlot'), (6, 'Italy', 'Belsito', 87, 16.0, 'Frappato'), (8, 'Germany', 'Shine', 87, 12.0, 'GewÃ¼rztraminer'), (9, 'France', 'Les Natures', 87, 27.0, 'Pinot Gris'), (10, 'US', 'Mountain CuvÃ©e', 87, 19.0, 'Cabernet Sauvignon')  ... displaying 10 of 86148 total bound parameter sets ...  (129968, 'France', 'Kritt', 90, 30.0, 'GewÃ¼rztraminer'), (129970, 'France', 'Lieu-dit Harth CuvÃ©e Caroline', 90, 21.0, 'GewÃ¼rztraminer'))
# 2019-05-11 15:31:01,718 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
country_transformed.to_sql(name='country_climates', con=engine, if_exists='append', index=True)
# Out:
# 2019-05-11 15:31:01,755 INFO sqlalchemy.engine.base.Engine DESCRIBE `country_climates`
# 2019-05-11 15:31:01,757 INFO sqlalchemy.engine.base.Engine ()
# 2019-05-11 15:31:01,765 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-05-11 15:31:01,770 INFO sqlalchemy.engine.base.Engine INSERT INTO country_climates (id, country, climate) VALUES (%s, %s, %s)
# 2019-05-11 15:31:01,772 INFO sqlalchemy.engine.base.Engine ((0, 'Afghanistan ', '1'), (1, 'Albania ', '3'), (2, 'Algeria ', '1'), (3, 'American Samoa ', '2'), (4, 'Andorra ', '3'), (6, 'Anguilla ', '2'), (7, 'Antigua & Barbuda ', '2'), (8, 'Argentina ', '3')  ... displaying 10 of 205 total bound parameter sets ...  (225, 'Zambia ', '2'), (226, 'Zimbabwe ', '2'))
# 2019-05-11 15:31:01,780 INFO sqlalchemy.engine.base.Engine COMMIT
